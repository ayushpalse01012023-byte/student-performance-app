# %%
from sklearn.linear_model import LogisticRegression

X= [[1], [2],[3],[4],[5],[6]]
y= [0, 0, 1, 1, 1, 1]

model = LogisticRegression()

model.fit(X,y)
hours = float(input("Enter the hours you stuied : "))
result = model.predict([[hours]])

if result == 1:
    print(f"passe with {hours} hours ")
else :
    print("Fail")
# Out:
# passe with 10.0 hours

# %%
from sklearn.linear_model import LogisticRegression

X= [[1], [2], [3], [4],[5],[6], [7], [8]]
y= [0, 0, 0, 0, 1, 1, 1, 1]

model = LogisticRegression()
model.fit(X,y)

hours = float(input("Enter the hours you slept : "))

final = model.predict([[hours]])
if final ==1:
    print(f"i am healthy because i slept for {hours} hours ")
else:
    print(f"i am unhealthy because i slept for {hours} hours ")
# Out:
# i am unhealthy because i slept for 2.0 hours

# %%
from sklearn.linear_model import LogisticRegression

X= [[20], [30], [40], [50], [60], [70],[75]]
y= [0, 0, 0, 1, 1, 1, 1]

model = LogisticRegression()
model.fit(X,y)

attendance = float(input("Enter yout attendance : "))

final = model.predict([[attendance]])
if final == 1:
 print("you are passesd ")
else:
 print("you are failed ")
# Out:
# you are passesd
